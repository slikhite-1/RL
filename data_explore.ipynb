# %%
pip install jsonlines
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import jsonlines

# %%
data_path = "/home/slikhite/slikhite-RL/datasets/bfcl_multiturn_filtered.jsonl"
with jsonlines.open(data_path, "r") as reader:
    data = [line for line in reader]

# %%
data[0].keys()
# Out:
# dict_keys(['messages', 'task_name', 'dataset'])

# %%
first_data = data[0]

len(first_data["messages"])

message_1 = first_data["messages"][0]
len(message_1)
# Out:
# 2

# %%
message_1[0]
# Out:
# {'role': 'system',
# ...

# %%
user_content =message_1[1]

# %%
user_content
# Out:
# {'role': 'user',
#  'content': "Move 'final_report.pdf' within document directory to 'temp' directory in document. Make sure to create the directory",
#  'metadata': {'id': 'multi_turn_base_0',
#   'initial_config': {'GorillaFileSystem': {'root': {'workspace': {'type': 'directory',
#       'contents': {'document': {'type': 'directory',
#         'contents': {'final_report.pdf': {'type': 'file',
#           'content': 'Year2024 This is the final report content including budget analysis and other sections.'},
#          'previous_report.pdf': {'type': 'file',
#           'content': 'Year203 This is the previous report content with different budget analysis.'}}},
#        'archive': {'type': 'directory', 'contents': {}}}}}},
#    'TwitterAPI': {'tweet_counter': 3,
#     'tweets': {'0': {'id': 0,
#       'username': 'analyst_pro',
#       'content': 'Just finished analyzing the reports!',
#       'tags': ['#analysis', '#reports'],
#       'mentions': []},
#      '1': {'id': 1,
# ...

# %%
user_content.keys()
# Out:
# dict_keys(['role', 'content', 'metadata'])

# %%
user_content['metadata'].keys()
# Out:
# dict_keys(['id', 'initial_config', 'involved_classes', 'path', 'ground_truth', 'user_question_bank', 'num_turns'])
